# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(style='white', palette='Set2')

# %matplotlib inline

from solutions_univ import histogram_solution_1

# %% [markdown]
# We'll continue working with the Pokémon dataset in this workspace.

# %%
pokemon = pd.read_csv('./data/pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# **Task**: Pokémon have a number of different statistics that describe their combat capabilities. Here, create a _histogram_ that depicts the distribution of 'special-defense' values taken. **Hint**: Try playing around with different bin width sizes to see what best depicts the data.

# %%
# YOUR CODE HERE
bins = np.arange(pokemon['special-defense'].min(), pokemon['special-defense'].max()+5, 5)

plt.figure(figsize=(8, 5))
sns.distplot(pokemon['special-defense'], bins=bins, color='#33b5e5', kde=False, hist_kws={'alpha': 1})
sns.despine(left=True)
plt.title('Distribution of pokemon`s special defense', fontdict={'fontsize': 20, 'fontweight': 'bold', 'color': '#404040'})
plt.show()

# %%
# run this cell to check your work against ours
histogram_solution_1()
# Out:
# I've used matplotlib's hist function to plot the data. I have also used numpy's arange function to set the bin edges. A bin size of 5 hits the main cut points, revealing a smooth, but skewed curves. Are there similar characteristics among Pokemon with the highest special defenses?
